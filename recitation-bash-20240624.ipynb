# %% [markdown]
# # the shell

# %% [markdown]
# Author: tienhoayu@gmail.com

# %%
! date
# Out:
# Mon Jun 24 20:58:10 CST 2024

# %%
! man echo
# Out:
# ECHO(1)                          User Commands                         ECHO(1)
#
# NAME
#        echo - display a line of text
#
# SYNOPSIS
#        echo [SHORT-OPTION]... [STRING]...
#        echo LONG-OPTION
#
# DESCRIPTION
#        Echo the STRING(s) to standard output.
#
#        -n     do not output the trailing newline
#
#        -e     enable interpretation of backslash escapes
#
#        -E     disable interpretation of backslash escapes (default)
#
#        --help display this help and exit
#
#        --version
#               output version information and exit
#
#        If -e is in effect, the following sequences are recognized:
#
#        \\     backslash
#
#        \a     alert (BEL)
#
#        \b     backspace
#
#        \c     produce no further output
#
#        \e     escape
#
#        \f     form feed
#
#        \n     new line
#
#        \r     carriage return
#
#        \t     horizontal tab
#
#        \v     vertical tab
#
# ...

# %%
! help
# Out:
# GNU bash, version 5.1.16(1)-release (x86_64-pc-linux-gnu)
# These shell commands are defined internally.  Type `help' to see this list.
# Type `help name' to find out more about the function `name'.
# Use `info bash' to find out more about the shell in general.
# Use `man -k' or `info' to find out more about commands not in this list.
#
# A star (*) next to a name means that the command is disabled.
#
#  job_spec [&]                            history [-c] [-d offset] [n] or hist>
#  (( expression ))                        if COMMANDS; then COMMANDS; [ elif C>
#  . filename [arguments]                  jobs [-lnprs] [jobspec ...] or jobs >
#  :                                       kill [-s sigspec | -n signum | -sigs>
#  [ arg... ]                              let arg [arg ...]
#  [[ expression ]]                        local [option] name[=value] ...
#  alias [-p] [name[=value] ... ]          logout [n]
# ...

# %%
! type echo
# Out:
# echo is a shell builtin

# %%
! type top
# Out:
# top is /usr/bin/top

# %% [markdown]
# read https://missing.csail.mit.edu/2020/shell-tools/

# %% [markdown]
# ## Learn More

# %% [markdown]
# get start:
#
# - (*) https://rubytune.com/cheat/
# - (*) https://gist.github.com/LeCoupa/122b12050f5fb267e75f
# - https://github.com/kevinthew/linuxgems/blob/master/cheat_sheet.org.sh
# - (*) https://ketancmaheshwari.github.io/pdfs/LPT_LISA.pdf You can find **everything** in this 100 pages file
# - https://github.com/r0f1/linuxhelp
# - https://learnxinyminutes.com/docs/bash/
# - https://talk.linuxtoy.org/cli-tips/
# - https://news.ycombinator.com/item?id=27042384
# - https://zwischenzugs.com/2018/01/06/ten-things-i-wish-id-known-about-bash/
# - https://robertmuth.blogspot.com/2012/08/better-bash-scripting-in-15-minutes.html

# %% [markdown]
# bash scirpt cheatsheet:
#
# - https://devhints.io/bash

# %% [markdown]
# modern commands:
#
# - https://remysharp.com/2018/08/23/cli-improved
# - https://github.com/ibraheemdev/modern-unix
# - https://codeahoy.com/2017/01/20/hhtop-explained-visually/
#
# my recommendation:
#
# - fuck
# - tldr, see https://tldr.inbrowser.app/pages/linux/top also

# %% [markdown]
# use python:
#
# - https://til.simonwillison.net/python/stdlib-cli-tools

# %% [markdown]
# shortcut:
#
# - https://gist.github.com/yelinaung/849c78c40784c56e05f5a04dded9082d
# - (*) https://clementc.github.io/blog/2018/01/25/moving_cli/
# - https://blog.fkz.tw/posts/2014/10/16/bash-cheat-sheet/
#
# *How Linux Works*
# ![image.png](attachment:943bc9a8-34d8-4d3b-8ae9-d2d0559d8bd3.png)
